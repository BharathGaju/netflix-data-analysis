# %% [markdown]
# ## Data Cleaning & Preparation
#
# **Objective:**
# Prepare the Netflix dataset for analysis by handling missing values, correcting data types, and creating derived features.
#
# **Key Steps Performed:**
# - Removed duplicates
# - Converted `date_added` to datetime format
# - Handled missing values in `country`, `rating`
# - Created time-based features (year, month)
