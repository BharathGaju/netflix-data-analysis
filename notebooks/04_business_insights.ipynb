# %% [markdown]
# ## Key Business Insights
#
# 1. Netflix rapidly scaled content additions post-2016
# 2. Movies form the majority of available content
# 3. US and India are strategic content hubs
#
# ## Business Recommendations
# - Increase regional content investment
# - Balance Movies vs TV Shows to improve retention
